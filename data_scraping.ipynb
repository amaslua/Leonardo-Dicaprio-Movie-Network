# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen

# %%
headers = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8', 'User-Agent': 'Mozilla/5.0'}

request = urllib.request.Request(url='https://www.themoviedb.org/person/6193-leonardo-dicaprio?language=en-US', headers=headers)
response = urllib.request.urlopen(request)
result = BeautifulSoup(response.read(), 'html.parser')

df = result.prettify()

# %%
movies = result.find('table', {'class': 'card credits'}).find_all('a', {'class':'tooltip'})
fullcast = []
for movie in movies:
    url = 'https://www.themoviedb.org' + movie['href']
    request = urllib.request.Request(url=url, headers=headers)
    response = urllib.request.urlopen(request)
    result = BeautifulSoup(response.read(), 'html.parser')

    x = result.find('p', {'class': 'new_button'})
    fullcast.append(x.findChild("a")['href'])

# %%
fullcast
# Out:
# ['/movie/803107-japanarama-psycho-tv-from-japan-vol-1/cast?language=en-US',
#  '/movie/1116712-the-incredible-life-of-leonardo-dicaprio-from-break-dance-to-oscar/cast?language=en-US',
#  '/movie/1054867-untitled-ck-pta-studio-feature-film/cast?language=en-US',
#  '/movie/1006179-the-wager/cast?language=en-US',
#  '/movie/823102-another-round/cast?language=en-US',
#  '/movie/895863-jim-jones/cast?language=en-US',
#  '/movie/486010-roosevelt/cast?language=en-US',
#  '/movie/438425-the-black-hand/cast?language=en-US',
#  '/movie/466420-killers-of-the-flower-moon/cast?language=en-US',
#  '/movie/1033548-brad-pitt-la-revanche-d-un-blond/cast?language=en-US',
#  '/movie/1065395-noi-siamo-cinema/cast?language=en-US',
#  '/movie/646380-don-t-look-up/cast?language=en-US',
#  '/movie/818082-salvator-mundi/cast?language=en-US',
#  '/movie/896633-adele-one-night-only/cast?language=en-US',
#  '/movie/881931-clint-eastwood-a-cinematic-legacy/cast?language=en-US',
#  '/movie/822099-the-lost-leonardo/cast?language=en-US',
#  '/movie/795859-kid-90/cast?language=en-US',
#  '/movie/792166-leonardo-dicaprio-most-wanted/cast?language=en-US',
#  '/tv/110343-whose-vote-counts-explained/cast?language=en-US',
#  '/tv/79525-the-last-dance/cast?language=en-US',
#  '/movie/669983-teslafy-me/cast?language=en-US',
#  '/movie/631143-qt8-the-first-eight/cast?language=en-US',
#  '/tv/92529-the-curse-of-don-s-plum/cast?language=en-US',
#  '/movie/466272-once-upon-a-time-in-hollywood/cast?language=en-US',
#  '/movie/599379-ice-on-fire/cast?language=en-US',
#  '/movie/621751-and-we-go-green/cast?language=en-US',
#  '/tv/83519-patriot-act-with-hasan-minhaj/cast?language=en-US',
#  '/movie/473888-ryuichi-sakamoto-coda/cast?language=en-US',
#  '/movie/467062-spielberg/cast?language=en-US',
#  '/movie/410718-before-the-flood/cast?language=en-US',
#  '/movie/402967-koko-the-gorilla-who-talks-to-people/cast?language=en-US',
#  '/tv/80547-re-view/cast?language=en-US',
#  '/movie/379053-a-world-unseen-the-revenant/cast?language=en-US',
#  '/movie/281957-the-revenant/cast?language=en-US',
#  '/movie/365717-the-audition/cast?language=en-US',
#  '/movie/696842-scorsese-s-goodfellas/cast?language=en-US',
#  '/movie/259465-the-wolf-pack/cast?language=en-US',
#  '/movie/106646-the-wolf-of-wall-street/cast?language=en-US',
#  '/movie/64682-the-great-gatsby/cast?language=en-US',
#  '/movie/68718-django-unchained/cast?language=en-US',
#  '/movie/213362-reflections-on-titanic/cast?language=en-US',
#  '/movie/88794-j-edgar/cast?language=en-US',
#  '/movie/80848-the-love-we-make/cast?language=en-US',
#  '/movie/27205-inception/cast?language=en-US',
#  '/movie/44992-imax-hubble/cast?language=en-US',
#  '/movie/11324-shutter-island/cast?language=en-US',
#  '/tv/30769-live-from-studio-five/cast?language=en-US',
#  '/movie/4148-revolutionary-road/cast?language=en-US',
#  '/movie/12113-body-of-lies/cast?language=en-US',
#  '/tv/23915-markus-lanz/cast?language=en-US',
#  '/movie/402970-notes-on-an-american-film-director-at-work/cast?language=en-US',
#  '/movie/4832-the-11th-hour/cast?language=en-US',
#  '/movie/36863-everything-s-cool/cast?language=en-US',
#  '/movie/1372-blood-diamond/cast?language=en-US',
#  '/movie/1422-the-departed/cast?language=en-US',
#  '/movie/1038873-earth-to-america/cast?language=en-US',
#  '/movie/949439-a-concert-for-hurricane-relief/cast?language=en-US',
#  '/movie/2567-the-aviator/cast?language=en-US',
#  '/tv/10946-celebrities-uncensored/cast?language=en-US',
#  '/movie/459682-catch-me-if-you-can-behind-the-camera/cast?language=en-US',
#  '/movie/640-catch-me-if-you-can/cast?language=en-US',
#  '/movie/3131-gangs-of-new-york/cast?language=en-US',
#  '/movie/75009-the-concert-for-new-york-city/cast?language=en-US',
#  '/movie/37857-don-s-plum/cast?language=en-US',
#  '/movie/656423-portrait-of-leonardo-the-kid-who-took-hollywood/cast?language=en-US',
#  '/movie/1907-the-beach/cast?language=en-US',
#  '/movie/294632-hangin-with-leo/cast?language=en-US',
#  '/tv/3167-the-early-show/cast?language=en-US',
#  '/movie/9466-celebrity/cast?language=en-US',
#  '/movie/9313-the-man-in-the-iron-mask/cast?language=en-US',
#  '/movie/597-titanic/cast?language=en-US',
#  '/tv/111979-leute-heute/cast?language=en-US',
#  '/tv/42265-taff/cast?language=en-US',
#  '/movie/9819-marvin-s-room/cast?language=en-US',
#  '/movie/454-romeo-juliet/cast?language=en-US',
#  '/tv/60971-critics-choice-movie-awards/cast?language=en-US',
#  '/movie/36834-total-eclipse/cast?language=en-US',
#  '/movie/10474-the-basketball-diaries/cast?language=en-US',
#  '/movie/12106-the-quick-and-the-dead/cast?language=en-US',
#  '/movie/376478-x-girl/cast?language=en-US',
#  '/movie/329216-the-foot-shooting-party/cast?language=en-US',
#  '/movie/1587-what-s-eating-gilbert-grape/cast?language=en-US',
#  '/movie/8092-this-boy-s-life/cast?language=en-US',
#  '/tv/27511-gmtv/cast?language=en-US',
#  '/tv/2518-the-tonight-show-with-jay-leno/cast?language=en-US',
#  '/movie/9264-poison-ivy/cast?language=en-US',
#  '/movie/12702-critters-3/cast?language=en-US',
#  '/tv/17482-parenthood/cast?language=en-US',
#  '/tv/8108-the-outsiders/cast?language=en-US',
#  '/tv/12390-the-new-lassie/cast?language=en-US',
#  '/movie/642488-mickey-s-safety-club-street-safe-street-smart/cast?language=en-US',
#  '/tv/2706-roseanne/cast?language=en-US',
#  '/tv/54-growing-pains/cast?language=en-US',
#  '/tv/1451-santa-barbara/cast?language=en-US',
#  '/tv/10918-wetten-dass/cast?language=en-US',
#  '/tv/1667-saturday-night-live/cast?language=en-US',
#  '/tv/27023-the-oscars/cast?language=en-US',
#  '/tv/10447-romper-room/cast?language=en-US',
#  '/tv/1709-today/cast?language=en-US']
